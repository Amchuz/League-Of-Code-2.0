# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from scipy.stats import zscore
import seaborn as sns
def cleaning(data):
    bank = pd.read_csv(data)
    bank.info()
    bank.rename( columns={'Unnamed: 0':'index'}, inplace=True )
    bank=bank.drop_duplicates()    
    bank.head(15)
    list1=['job','marital','education','default','housing','loan','contact','month','poutcome','y']
    for l in list1:
        sns.countplot(y=l, data=bank, order = bank[l].value_counts().index)
        plt.show()
    bank.hist(figsize=(10,10), xrot=-45)
    plt.show()
    sns.heatmap(bank.isnull())
    bank.isnull().sum()
    print(bank.isnull().values.any())
    bank = bank[bank.job != 'unknown']
    bank = bank[bank.marital != 'unknown']
    bank = bank[bank.education != 'unknown']
    del bank['default']
    del bank['duration']
    del bank['contact']
    bank.info()
    bank["month"].replace({"jan": 1,"feb": 2,"mar": 3,"apr": 4, "may": 5, "jun": 6,"jul": 7,"aug": 8,"sep": 9,"oct": 10,"nov": 11,"dec": 12,}, inplace=True)
    bank.head(20)
    sns.boxplot(x=bank['balance'])
    bank[['balance']].mean()
    bank['outliers'] = zscore(bank['balance'])
    check = (bank['outliers']>3) | (bank['outliers']<-3 )
    bank = bank.drop(bank[check].index, axis = 0, inplace = False)
    bank = bank.drop('outliers', axis=1)
    sns.boxplot(x=bank['balance'])
    bank.job.replace(['retired', 'unemployed'], 'no_active_income', inplace=True)
    bank.marital.replace(['single', 'divorced'], 'single', inplace=True)
    list1=['job','marital','education','housing','loan','month','poutcome','y']
    for l in list1:
        sns.countplot(y=l, data=bank, order = bank[l].value_counts().index)
        plt.show()
    bank.job.replace(['entrepreneur', 'self-employed'], 'self-employed', inplace=True)
    bank.job.replace(['admin.', 'management'], 'admini_management', inplace=True)
    bank.job.replace(['blue-collar', 'technician'], 'blue-collar', inplace=True)
    bank.rename(index=str, columns={'y': 'result'}, inplace = True)
    bank.head(50)
    bank.to_csv('cleaned_data.csv',index=False)

# %%
cleaning("bank-full.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# False
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43193 entries, 0 to 45210
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        43193 non-null  int64
#  1   job        43193 non-null  object
#  2   marital    43193 non-null  object
#  3   education  43193 non-null  object
#  4   balance    43193 non-null  int64
#  5   housing    43193 non-null  object
#  6   loan       43193 non-null  object
#  7   day        43193 non-null  int64
#  8   month      43193 non-null  object
#  9   campaign   43193 non-null  int64
#  10  pdays      43193 non-null  int64
#  11  previous   43193 non-null  int64
#  12  poutcome   43193 non-null  object
#  13  y          43193 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 4.9+ MB

# %%
df=pd.read_csv("cleaned_data.csv")
df.head(50)
# Out:
#     age                job  marital  education  balance housing loan  day  \
# 0    58  admini_management  married   tertiary     2143     yes   no    5
# 1    44        blue-collar   single  secondary       29     yes   no    5
# 2    33      self-employed  married  secondary        2     yes  yes    5
# 3    35  admini_management  married   tertiary      231     yes   no    5
# 4    28  admini_management   single   tertiary      447     yes  yes    5
# 5    42      self-employed   single   tertiary        2     yes   no    5
# 6    58   no_active_income  married    primary      121     yes   no    5
# 7    43        blue-collar   single  secondary      593     yes   no    5
# 8    41  admini_management   single  secondary      270     yes   no    5
# 9    29  admini_management   single  secondary      390     yes   no    5
# 10   53        blue-collar  married  secondary        6     yes   no    5
# 11   57           services  married  secondary      162     yes   no    5
# 12   51   no_active_income  married    primary      229     yes   no    5
# 13   57        blue-collar  married    primary       52     yes   no    5
# 14   60   no_active_income  married    primary       60     yes   no    5
# 15   33           services  married  secondary        0     yes   no    5
# 16   28        blue-collar  married  secondary      723     yes  yes    5
# 17   56  admini_management  married   tertiary      779     yes   no    5
# 18   32        blue-collar   single    primary       23     yes  yes    5
# 19   25           services  married  secondary       50     yes   no    5
# 20   40   no_active_income  married    primary        0     yes  yes    5
# 21   44  admini_management  married  secondary     -372     yes   no    5
# 22   39  admini_management   single   tertiary      255     yes   no    5
# 23   52      self-employed  married  secondary      113     yes  yes    5
# 24   46  admini_management   single  secondary     -246     yes   no    5
# 25   36        blue-collar   single  secondary      265     yes  yes    5
# 26   57        blue-collar  married  secondary      839      no  yes    5
# 27   49  admini_management  married   tertiary      378     yes   no    5
# 28   60  admini_management  married  secondary       39     yes  yes    5
# 29   59        blue-collar  married  secondary        0     yes   no    5
# 30   57        blue-collar   single  secondary       63     yes   no    5
# 31   25        blue-collar  married  secondary       -7     yes   no    5
# 32   53        blue-collar  married  secondary       -3      no   no    5
# 33   36  admini_management   single  secondary      506     yes   no    5
# 34   37  admini_management   single  secondary        0     yes   no    5
# 35   44           services   single  secondary     2586     yes   no    5
# 36   50  admini_management  married  secondary       49     yes   no    5
# 37   54   no_active_income  married  secondary      529     yes   no    5
# 38   36  admini_management   single    primary     -171     yes   no    5
# 39   58      self-employed  married   tertiary     -364     yes   no    5
# 40   44        blue-collar  married  secondary        0     yes   no    5
# 41   55        blue-collar   single  secondary        0      no   no    5
# 42   29  admini_management   single   tertiary        0     yes   no    5
# 43   54        blue-collar  married  secondary     1291     yes   no    5
# 44   48  admini_management   single   tertiary     -244     yes   no    5
# 45   32  admini_management  married   tertiary        0     yes   no    5
# 46   42  admini_management   single  secondary      -76     yes   no    5
# 47   24        blue-collar   single  secondary     -103     yes  yes    5
# 48   38      self-employed   single   tertiary      243      no  yes    5
# 49   38  admini_management   single   tertiary      424     yes   no    5
#
#     month  campaign  pdays  previous poutcome result
# 0       5         1     -1         0  unknown     no
# 1       5         1     -1         0  unknown     no
# 2       5         1     -1         0  unknown     no
# 3       5         1     -1         0  unknown     no
# 4       5         1     -1         0  unknown     no
# 5       5         1     -1         0  unknown     no
# 6       5         1     -1         0  unknown     no
# 7       5         1     -1         0  unknown     no
# 8       5         1     -1         0  unknown     no
# 9       5         1     -1         0  unknown     no
# 10      5         1     -1         0  unknown     no
# 11      5         1     -1         0  unknown     no
# 12      5         1     -1         0  unknown     no
# 13      5         1     -1         0  unknown     no
# 14      5         1     -1         0  unknown     no
# 15      5         1     -1         0  unknown     no
# 16      5         1     -1         0  unknown     no
# 17      5         1     -1         0  unknown     no
# 18      5         1     -1         0  unknown     no
# 19      5         1     -1         0  unknown     no
# 20      5         1     -1         0  unknown     no
# 21      5         1     -1         0  unknown     no
# 22      5         1     -1         0  unknown     no
# 23      5         1     -1         0  unknown     no
# 24      5         2     -1         0  unknown     no
# 25      5         1     -1         0  unknown     no
# 26      5         1     -1         0  unknown     no
# 27      5         1     -1         0  unknown     no
# 28      5         1     -1         0  unknown     no
# 29      5         1     -1         0  unknown     no
# 30      5         1     -1         0  unknown     no
# 31      5         1     -1         0  unknown     no
# 32      5         1     -1         0  unknown     no
# 33      5         1     -1         0  unknown     no
# 34      5         1     -1         0  unknown     no
# 35      5         1     -1         0  unknown     no
# 36      5         2     -1         0  unknown     no
# 37      5         1     -1         0  unknown     no
# 38      5         1     -1         0  unknown     no
# 39      5         1     -1         0  unknown     no
# 40      5         2     -1         0  unknown     no
# 41      5         1     -1         0  unknown     no
# 42      5         1     -1         0  unknown     no
# 43      5         1     -1         0  unknown     no
# 44      5         1     -1         0  unknown     no
# 45      5         1     -1         0  unknown     no
# 46      5         1     -1         0  unknown     no
# 47      5         1     -1         0  unknown     no
# 48      5         1     -1         0  unknown     no
# 49      5         1     -1         0  unknown     no

# %%
bank=bank.drop_duplicates()

# %%
bank.shape
# Out:
# (45211, 17)

# %%
bank.head(15)
# Out:
#     age                job  marital  education  balance housing loan  day  \
# 0    58  admini_management  married   tertiary     2143     yes   no    5
# 1    44        blue-collar   single  secondary       29     yes   no    5
# 2    33      self-employed  married  secondary        2     yes  yes    5
# 5    35  admini_management  married   tertiary      231     yes   no    5
# 6    28  admini_management   single   tertiary      447     yes  yes    5
# 7    42      self-employed   single   tertiary        2     yes   no    5
# 8    58   no_active_income  married    primary      121     yes   no    5
# 9    43        blue-collar   single  secondary      593     yes   no    5
# 10   41  admini_management   single  secondary      270     yes   no    5
# 11   29  admini_management   single  secondary      390     yes   no    5
# 12   53        blue-collar  married  secondary        6     yes   no    5
# 14   57           services  married  secondary      162     yes   no    5
# 15   51   no_active_income  married    primary      229     yes   no    5
# 17   57        blue-collar  married    primary       52     yes   no    5
# 18   60   no_active_income  married    primary       60     yes   no    5
#
#     month  campaign  pdays  previous poutcome result
# 0       5         1     -1         0  unknown     no
# 1       5         1     -1         0  unknown     no
# 2       5         1     -1         0  unknown     no
# 5       5         1     -1         0  unknown     no
# 6       5         1     -1         0  unknown     no
# 7       5         1     -1         0  unknown     no
# 8       5         1     -1         0  unknown     no
# 9       5         1     -1         0  unknown     no
# 10      5         1     -1         0  unknown     no
# 11      5         1     -1         0  unknown     no
# 12      5         1     -1         0  unknown     no
# 14      5         1     -1         0  unknown     no
# 15      5         1     -1         0  unknown     no
# 17      5         1     -1         0  unknown     no
# 18      5         1     -1         0  unknown     no

# %%
bank.tail(15)
# Out:
#        age                job  marital  education  balance housing loan  day  \
# 45196   25            student   single  secondary      358      no   no   16
# 45197   36  admini_management   single  secondary     1511     yes   no   16
# 45198   37  admini_management  married   tertiary     1428      no   no   16
# 45199   34        blue-collar   single  secondary     1475     yes   no   16
# 45200   38        blue-collar  married  secondary      557     yes   no   16
# 45201   53  admini_management  married   tertiary      583      no   no   17
# 45202   34  admini_management   single  secondary      557      no   no   17
# 45203   23            student   single   tertiary      113      no   no   17
# 45204   73   no_active_income  married  secondary     2850      no   no   17
# 45205   25        blue-collar   single  secondary      505      no  yes   17
# 45206   51        blue-collar  married   tertiary      825      no   no   17
# 45207   71   no_active_income   single    primary     1729      no   no   17
# 45208   72   no_active_income  married  secondary     5715      no   no   17
# 45209   57        blue-collar  married  secondary      668      no   no   17
# 45210   37      self-employed  married  secondary     2971      no   no   17
#
#        month  campaign  pdays  previous poutcome result
# 45196     11         1     -1         0  unknown    yes
# 45197     11         1     -1         0  unknown    yes
# 45198     11         2     -1         0  unknown     no
# 45199     11         3    530        12    other     no
# 45200     11         4     -1         0  unknown    yes
# 45201     11         1    184         4  success    yes
# 45202     11         1     -1         0  unknown    yes
# 45203     11         1     -1         0  unknown    yes
# 45204     11         1     40         8  failure    yes
# 45205     11         2     -1         0  unknown    yes
# 45206     11         3     -1         0  unknown    yes
# 45207     11         2     -1         0  unknown    yes
# 45208     11         5    184         3  success    yes
# 45209     11         4     -1         0  unknown     no
# 45210     11         2    188        11    other     no

# %%
list1=['job','marital','education','default','housing','loan','contact','month','poutcome','y']
for l in list1:
    sns.countplot(y=l, data=bank, order = bank[l].value_counts().index)
    plt.show()

# %%
bank.hist(figsize=(10,10), xrot=-45)
plt.show()

# %%
sns.heatmap(bank.isnull())

# %%
bank.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
print(bank.isnull().values.any())
# Out:
# False

# %%
bank = bank[bank.job != 'unknown']
bank = bank[bank.marital != 'unknown']
bank = bank[bank.education != 'unknown']

del bank['default']
del bank['duration']
del bank['contact']
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43193 entries, 0 to 45210
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        43193 non-null  int64
#  1   job        43193 non-null  object
#  2   marital    43193 non-null  object
#  3   education  43193 non-null  object
#  4   balance    43193 non-null  int64
#  5   housing    43193 non-null  object
#  6   loan       43193 non-null  object
#  7   day        43193 non-null  int64
#  8   month      43193 non-null  object
#  9   campaign   43193 non-null  int64
#  10  pdays      43193 non-null  int64
#  11  previous   43193 non-null  int64
#  12  poutcome   43193 non-null  object
#  13  y          43193 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 4.9+ MB

# %%
bank["month"].replace({"jan": 1,"feb": 2,"mar": 3,"apr": 4, "may": 5, "jun": 6,"jul": 7,"aug": 8,"sep": 9,"oct": 10,"nov": 11,"dec": 12,}, inplace=True)
bank.head(20)
# Out:
#     age           job   marital  education  balance housing loan  day  month  \
# 0    58    management   married   tertiary     2143     yes   no    5      5
# 1    44    technician    single  secondary       29     yes   no    5      5
# 2    33  entrepreneur   married  secondary        2     yes  yes    5      5
# 5    35    management   married   tertiary      231     yes   no    5      5
# 6    28    management    single   tertiary      447     yes  yes    5      5
# 7    42  entrepreneur  divorced   tertiary        2     yes   no    5      5
# 8    58       retired   married    primary      121     yes   no    5      5
# 9    43    technician    single  secondary      593     yes   no    5      5
# 10   41        admin.  divorced  secondary      270     yes   no    5      5
# 11   29        admin.    single  secondary      390     yes   no    5      5
# 12   53    technician   married  secondary        6     yes   no    5      5
# 14   57      services   married  secondary      162     yes   no    5      5
# 15   51       retired   married    primary      229     yes   no    5      5
# 17   57   blue-collar   married    primary       52     yes   no    5      5
# 18   60       retired   married    primary       60     yes   no    5      5
# 19   33      services   married  secondary        0     yes   no    5      5
# 20   28   blue-collar   married  secondary      723     yes  yes    5      5
# 21   56    management   married   tertiary      779     yes   no    5      5
# 22   32   blue-collar    single    primary       23     yes  yes    5      5
# 23   25      services   married  secondary       50     yes   no    5      5
#
#     campaign  pdays  previous poutcome   y
# 0          1     -1         0  unknown  no
# 1          1     -1         0  unknown  no
# 2          1     -1         0  unknown  no
# 5          1     -1         0  unknown  no
# 6          1     -1         0  unknown  no
# 7          1     -1         0  unknown  no
# 8          1     -1         0  unknown  no
# 9          1     -1         0  unknown  no
# 10         1     -1         0  unknown  no
# 11         1     -1         0  unknown  no
# 12         1     -1         0  unknown  no
# 14         1     -1         0  unknown  no
# 15         1     -1         0  unknown  no
# 17         1     -1         0  unknown  no
# 18         1     -1         0  unknown  no
# 19         1     -1         0  unknown  no
# 20         1     -1         0  unknown  no
# 21         1     -1         0  unknown  no
# 22         1     -1         0  unknown  no
# 23         1     -1         0  unknown  no

# %%
sns.boxplot(x=bank['balance'])

# %%
bank[['balance']].mean()

bank['outliers'] = zscore(bank['balance'])

check = (bank['outliers']>3) | (bank['outliers']<-3 )
bank = bank.drop(bank[check].index, axis = 0, inplace = False)

bank = bank.drop('outliers', axis=1)

# %%
sns.boxplot(x=bank['balance'])

# %%
bank.job.replace(['retired', 'unemployed'], 'no_active_income', inplace=True)
bank.marital.replace(['single', 'divorced'], 'single', inplace=True)

# %%
list1=['job','marital','education','housing','loan','month','poutcome','y']
for l in list1:
    sns.countplot(y=l, data=bank, order = bank[l].value_counts().index)
    plt.show()

# %%
bank.job.replace(['entrepreneur', 'self-employed'], 'self-employed', inplace=True)
bank.job.replace(['admin.', 'management'], 'admini_management', inplace=True)
bank.job.replace(['blue-collar', 'technician'], 'blue-collar', inplace=True)

# %%
bank.rename(index=str, columns={'y': 'result'}, inplace = True)

# %%
bank.head(50)
# Out:
#     age                job  marital  education  balance housing loan  day  \
# 0    58  admini_management  married   tertiary     2143     yes   no    5
# 1    44        blue-collar   single  secondary       29     yes   no    5
# 2    33      self-employed  married  secondary        2     yes  yes    5
# 5    35  admini_management  married   tertiary      231     yes   no    5
# 6    28  admini_management   single   tertiary      447     yes  yes    5
# 7    42      self-employed   single   tertiary        2     yes   no    5
# 8    58   no_active_income  married    primary      121     yes   no    5
# 9    43        blue-collar   single  secondary      593     yes   no    5
# 10   41  admini_management   single  secondary      270     yes   no    5
# 11   29  admini_management   single  secondary      390     yes   no    5
# 12   53        blue-collar  married  secondary        6     yes   no    5
# 14   57           services  married  secondary      162     yes   no    5
# 15   51   no_active_income  married    primary      229     yes   no    5
# 17   57        blue-collar  married    primary       52     yes   no    5
# 18   60   no_active_income  married    primary       60     yes   no    5
# 19   33           services  married  secondary        0     yes   no    5
# 20   28        blue-collar  married  secondary      723     yes  yes    5
# 21   56  admini_management  married   tertiary      779     yes   no    5
# 22   32        blue-collar   single    primary       23     yes  yes    5
# 23   25           services  married  secondary       50     yes   no    5
# 24   40   no_active_income  married    primary        0     yes  yes    5
# 25   44  admini_management  married  secondary     -372     yes   no    5
# 26   39  admini_management   single   tertiary      255     yes   no    5
# 27   52      self-employed  married  secondary      113     yes  yes    5
# 28   46  admini_management   single  secondary     -246     yes   no    5
# 29   36        blue-collar   single  secondary      265     yes  yes    5
# 30   57        blue-collar  married  secondary      839      no  yes    5
# 31   49  admini_management  married   tertiary      378     yes   no    5
# 32   60  admini_management  married  secondary       39     yes  yes    5
# 33   59        blue-collar  married  secondary        0     yes   no    5
# 35   57        blue-collar   single  secondary       63     yes   no    5
# 36   25        blue-collar  married  secondary       -7     yes   no    5
# 37   53        blue-collar  married  secondary       -3      no   no    5
# 38   36  admini_management   single  secondary      506     yes   no    5
# 39   37  admini_management   single  secondary        0     yes   no    5
# 40   44           services   single  secondary     2586     yes   no    5
# 41   50  admini_management  married  secondary       49     yes   no    5
# 43   54   no_active_income  married  secondary      529     yes   no    5
# 45   36  admini_management   single    primary     -171     yes   no    5
# 46   58      self-employed  married   tertiary     -364     yes   no    5
# 47   44        blue-collar  married  secondary        0     yes   no    5
# 48   55        blue-collar   single  secondary        0      no   no    5
# 49   29  admini_management   single   tertiary        0     yes   no    5
# 50   54        blue-collar  married  secondary     1291     yes   no    5
# 51   48  admini_management   single   tertiary     -244     yes   no    5
# 52   32  admini_management  married   tertiary        0     yes   no    5
# 53   42  admini_management   single  secondary      -76     yes   no    5
# 54   24        blue-collar   single  secondary     -103     yes  yes    5
# 55   38      self-employed   single   tertiary      243      no  yes    5
# 56   38  admini_management   single   tertiary      424     yes   no    5
#
#     month  campaign  pdays  previous poutcome result
# 0       5         1     -1         0  unknown     no
# 1       5         1     -1         0  unknown     no
# 2       5         1     -1         0  unknown     no
# 5       5         1     -1         0  unknown     no
# 6       5         1     -1         0  unknown     no
# 7       5         1     -1         0  unknown     no
# 8       5         1     -1         0  unknown     no
# 9       5         1     -1         0  unknown     no
# 10      5         1     -1         0  unknown     no
# 11      5         1     -1         0  unknown     no
# 12      5         1     -1         0  unknown     no
# 14      5         1     -1         0  unknown     no
# 15      5         1     -1         0  unknown     no
# 17      5         1     -1         0  unknown     no
# 18      5         1     -1         0  unknown     no
# 19      5         1     -1         0  unknown     no
# 20      5         1     -1         0  unknown     no
# 21      5         1     -1         0  unknown     no
# 22      5         1     -1         0  unknown     no
# 23      5         1     -1         0  unknown     no
# 24      5         1     -1         0  unknown     no
# 25      5         1     -1         0  unknown     no
# 26      5         1     -1         0  unknown     no
# 27      5         1     -1         0  unknown     no
# 28      5         2     -1         0  unknown     no
# 29      5         1     -1         0  unknown     no
# 30      5         1     -1         0  unknown     no
# 31      5         1     -1         0  unknown     no
# 32      5         1     -1         0  unknown     no
# 33      5         1     -1         0  unknown     no
# 35      5         1     -1         0  unknown     no
# 36      5         1     -1         0  unknown     no
# 37      5         1     -1         0  unknown     no
# 38      5         1     -1         0  unknown     no
# 39      5         1     -1         0  unknown     no
# 40      5         1     -1         0  unknown     no
# 41      5         2     -1         0  unknown     no
# 43      5         1     -1         0  unknown     no
# 45      5         1     -1         0  unknown     no
# 46      5         1     -1         0  unknown     no
# 47      5         2     -1         0  unknown     no
# 48      5         1     -1         0  unknown     no
# 49      5         1     -1         0  unknown     no
# 50      5         1     -1         0  unknown     no
# 51      5         1     -1         0  unknown     no
# 52      5         1     -1         0  unknown     no
# 53      5         1     -1         0  unknown     no
# 54      5         1     -1         0  unknown     no
# 55      5         1     -1         0  unknown     no
# 56      5         1     -1         0  unknown     no

# %%
bank.to_csv('cleaned_data.csv')
